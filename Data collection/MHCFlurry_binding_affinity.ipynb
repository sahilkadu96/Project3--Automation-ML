# %%
# !pip install mhcflurry
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mhcflurry
#   Downloading mhcflurry-2.0.6-py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.8/140.8 KB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.20.3 in /usr/local/lib/python3.8/dist-packages (from mhcflurry) (1.3.5)
# Collecting mhcgnomes>=0.8.4
#   Downloading mhcgnomes-1.8.4-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.7/103.7 KB 14.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from mhcflurry) (4.64.1)
# Collecting np-utils
#   Downloading np_utils-0.6.0.tar.gz (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 KB 9.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: appdirs in /usr/local/lib/python3.8/dist-packages (from mhcflurry) (1.4.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from mhcflurry) (6.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from mhcflurry) (1.2.1)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from mhcflurry) (1.15.0)
# Collecting serializable
#   Downloading serializable-0.2.1.tar.gz (8.4 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pyyaml
#   Downloading PyYAML-5.4-cp38-cp38-manylinux1_x86_64.whl (662 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 662.2/662.2 KB 24.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from mhcgnomes>=0.8.4->mhcflurry) (1.22.4)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.20.3->mhcflurry) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.20.3->mhcflurry) (2.8.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->mhcflurry) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->mhcflurry) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->mhcflurry) (3.1.0)
# Collecting typechecks>=0.0.2
#   Downloading typechecks-0.1.0.tar.gz (3.4 kB)
#   Preparing metadata (setup.py) ... done
# Collecting simplejson
#   Downloading simplejson-3.18.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.5/135.5 KB 18.0 MB/s eta 0:00:00
# Building wheels for collected packages: np-utils, serializable, typechecks
#   Building wheel for np-utils (setup.py) ... done
#   Created wheel for np-utils: filename=np_utils-0.6.0-py3-none-any.whl size=56460 sha256=cca88ee2a2223f713f1a5b925f1635a56b7720413d5baf4eadfef1226f3e9dda
#   Stored in directory: /root/.cache/pip/wheels/55/8b/e7/a23fd46c709c21e3e6fcb55978d88b018f80d54018459978c3
#   Building wheel for serializable (setup.py) ... done
#   Created wheel for serializable: filename=serializable-0.2.1-py3-none-any.whl size=8959 sha256=c2ec9bf1c73f0a431aa34b21d9184b5f875a49e371f4a8c4604d5f5a8f4c5b49
#   Stored in directory: /root/.cache/pip/wheels/17/ce/b1/a5a8c5d54b8ca1218d5e79837455a697a568824213a54e4f2a
#   Building wheel for typechecks (setup.py) ... done
#   Created wheel for typechecks: filename=typechecks-0.1.0-py3-none-any.whl size=2770 sha256=6eff035960f049321596549a54f9b250593d574cdcc62fb9462e2c2e5f7905dc
#   Stored in directory: /root/.cache/pip/wheels/b8/e8/8b/ccc70fc4afb29a46271f1006b94357df986b3978bb4af7909a
# Successfully built np-utils serializable typechecks
# Installing collected packages: typechecks, simplejson, pyyaml, np-utils, serializable, mhcgnomes, mhcflurry
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
# Successfully installed mhcflurry-2.0.6 mhcgnomes-1.8.4 np-utils-0.6.0 pyyaml-5.4 serializable-0.2.1 simplejson-3.18.3 typechecks-0.1.0

# %%
! mhcflurry-downloads fetch
# Out:
# Fetching 3/22 downloads from release 2.0.0
# DOWNLOAD NAME                             ALREADY DOWNLOADED?    WILL DOWNLOAD NOW?    URL
# models_class1_pan                         NO                     NO                    https://github.com/openvax/mhcflurry/releases/download/pre-2.0/models_class1_pan.selected.20200610.tar.bz2
# models_class1_presentation                NO                     YES                   https://github.com/openvax/mhcflurry/releases/download/pre-2.0/models_class1_presentation.20200611.tar.bz2
# models_class1_processing                  NO                     NO                    https://github.com/openvax/mhcflurry/releases/download/pre-2.0/models_class1_processing.selected.20200611.tar.bz2
# models_class1_pan_unselected              NO                     NO                    https://github.com/openvax/mhcflurry/releases/download/pre-2.0/models_class1_pan.20200610.tar.bz2
# models_class1_pan_variants                NO                     NO                    https://github.com/openvax/mhcflurry/releases/download/pre-2.0/models_class1_pan_variants.selected.20200610.tar.bz2
# data_evaluation                           NO                     NO                    https://github.com/openvax/mhcflurry/releases/download/pre-2.0/data_evaluation.20200611.tar.bz2.part.aa + 2 more parts
# analysis_predictor_info                   NO                     NO                    https://github.com/openvax/mhcflurry/releases/download/pre-2.0/analysis_predictor_info.20200711.tar.bz2
# data_predictions                          NO                     NO                    https://github.com/openvax/mhcflurry/releases/download/pre-2.0/data_predictions.20200713.tar.bz2.part.aa + 11 more parts
# data_mass_spec_annotated                  NO                     NO                    https://github.com/openvax/mhcflurry/releases/download/1.6.0/data_mass_spec_annotated.20191226.tar.bz2
# data_references                           NO                     NO                    https://github.com/openvax/mhcflurry/releases/download/pre-1.4.0/data_references.20190927.tar.bz2
# data_iedb                                 NO                     NO                    https://github.com/openvax/mhcflurry/releases/download/pre-1.7.0/data_iedb.20200427.tar.bz2
# data_systemhcatlas                        NO                     NO                    http://github.com/openvax/mhcflurry/releases/download/pan-dev1/data_systemhcatlas.20190506.tar.bz2
# allele_sequences                          NO                     NO                    https://github.com/openvax/mhcflurry/releases/download/1.4.0/allele_sequences.20191231.tar.bz2
# random_peptide_predictions                NO                     NO                    http://github.com/openvax/mhcflurry/releases/download/pan-dev1/random_peptide_predictions.20190506.tar.bz2
# data_published                            NO                     NO                    https://github.com/openvax/mhcflurry/releases/download/pre-1.7.0/data_published.20200501.tar.bz2
# data_curated                              NO                     YES                   https://github.com/openvax/mhcflurry/releases/download/pre-1.7.0/data_curated.20200427.tar.bz2
# models_class1                             NO                     YES                   http://github.com/openvax/mhcflurry/releases/download/pre-1.2/models_class1.20180225.tar.bz2
# models_class1_selected_no_mass_spec       NO                     NO                    http://github.com/openvax/mhcflurry/releases/download/pre-1.2/models_class1_selected_no_mass_spec.20180225.tar.bz2
# models_class1_unselected                  NO                     NO                    http://github.com/openvax/mhcflurry/releases/download/pre-1.2/models_class1_unselected.20180221.tar.bz2
# models_class1_trained_with_mass_spec      NO                     NO                    http://github.com/openvax/mhcflurry/releases/download/pre-1.2.1/models_class1_trained_with_mass_spec.20180228.tar.bz2
# models_class1_unselected_with_mass_spec   NO                     NO                    http://github.com/openvax/mhcflurry/releases/download/pre-1.2.1/models_class1_unselected_with_mass_spec.20180227.tar.bz2
# models_class1_minimal                     NO                     NO                    http://github.com/openvax/mhcflurry/releases/download/pre-1.2/models_class1_minimal.20180226.tar.bz2
# Downloading [part 1/1]: https://github.com/openvax/mhcflurry/releases/download/pre-2.0/models_class1_presentation.20200611.tar.bz2
# 135MB [00:02, 65.2MB/s]
# Downloaded to: /tmp/tmp3s4bo5sa.tar.bz2
# Extracting: 100% 62/62 [00:11<00:00,  5.18it/s]
# Extracted 62 files to: /root/.local/share/mhcflurry/4/2.0.0/models_class1_presentation/
# Downloading [part 1/1]: http://github.com/openvax/mhcflurry/releases/download/pre-1.2/models_class1.20180225.tar.bz2
# 72.6MB [00:01, 44.8MB/s]
# Downloaded to: /tmp/tmpfw6t1bu1.tar.bz2
# Extracting: 100% 1429/1429 [00:06<00:00, 219.94it/s]
# Extracted 1429 files to: /root/.local/share/mhcflurry/4/2.0.0/models_class1/
# Downloading [part 1/1]: https://github.com/openvax/mhcflurry/releases/download/pre-1.7.0/data_curated.20200427.tar.bz2
# 73.4MB [00:01, 42.9MB/s]
# Downloaded to: /tmp/tmpuyaueb7d.tar.bz2
# Extracting: 100% 30/30 [00:10<00:00,  2.90it/s]
# Extracted 30 files to: /root/.local/share/mhcflurry/4/2.0.0/data_curated/

# %%
from mhcflurry import Class1PresentationPredictor

# %%
predictor = Class1PresentationPredictor.load()
# Out:
# Forcing tensorflow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/mhcflurry/common.py:131: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/initializers/initializers_v1.py:297: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
predictor.predict(
    peptides=["SIINFEKL", "NLVPMVATV"],
    alleles=["HLA-A0201", "HLA-A0301"],
    verbose=0)
# Out:
# /usr/local/lib/python3.8/dist-packages/keras/engine/training_v1.py:2357: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/init_ops.py:93: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/init_ops.py:93: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
#      peptide  peptide_num sample_name      affinity best_allele  \
# 0   SIINFEKL            0     sample1  11927.159038   HLA-A0201
# 1  NLVPMVATV            1     sample1     16.570969   HLA-A0201
#
#    processing_score  presentation_score  presentation_percentile
# 0          0.264710            0.020690                11.630326
# 1          0.533008            0.970187                 0.018723

# %%
predictor.predict(
    peptides=["KSEYMTSWFY", "NLVPMVATV"],
    alleles={
       "sample1": ["A0201", "A0301", "B0702", "B4402", "C0201", "C0702"],
       "sample2": ["A0101", "A0206", "B5701", "C0202"],
    },
    verbose=0)
# Out:
#       peptide  peptide_num sample_name     affinity best_allele  \
# 0  KSEYMTSWFY            0     sample1  8292.187654       C0201
# 1   NLVPMVATV            1     sample1    16.570969       A0201
# 2  KSEYMTSWFY            0     sample2    88.898432       A0101
# 3   NLVPMVATV            1     sample2    17.406644       A0206
#
#    processing_score  presentation_score  presentation_percentile
# 0          0.542474            0.074376                 3.639185
# 1          0.533008            0.970187                 0.018723
# 2          0.542474            0.868106                 0.171848
# 3          0.533008            0.968773                 0.021413

# %%
predictor.predict_sequences(
   sequences={
       'protein1': "MDSKGSSQKGSRLLLLLVVSNLL",
       'protein2': "SSLPTPEDKEQAQQTHH",
   },
   alleles={
       "sample1": ["A0201", "A0301", "B0702"],
       "sample2": ["A0101", "C0202"],
   },
   result="filtered",
   comparison_quantity="affinity",
   filter_value=500,
   verbose=0)
# Out:
# /usr/local/lib/python3.8/dist-packages/keras/engine/training_v1.py:2357: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
#   sequence_name  pos     peptide n_flank c_flank sample_name    affinity  \
# 0      protein1   14   LLLVVSNLL   GSRLL             sample1   57.180481
# 1      protein1   13   LLLLVVSNL   KGSRL       L     sample1   57.338895
# 2      protein1    5   SSQKGSRLL   MDSKG   LLLVV     sample2  110.778556
# 3      protein1    6   SQKGSRLLL   DSKGS   LLVVS     sample2  254.479947
# 4      protein1   13  LLLLVVSNLL   KGSRL             sample1  260.390387
# 5      protein1   12  LLLLLVVSNL   QKGSR       L     sample1  308.149651
# 6      protein2    0   SSLPTPEDK           EQAQQ     sample2  410.354205
# 7      protein1    5    SSQKGSRL   MDSKG   LLLLV     sample2  444.320713
# 8      protein2    0   SSLPTPEDK           EQAQQ     sample1  459.295795
# 9      protein1    4   GSSQKGSRL    MDSK   LLLLV     sample2  469.052423
#
#   best_allele  affinity_percentile  processing_score  presentation_score  \
# 0       A0201             0.398125          0.233159            0.754186
# 1       A0201             0.398125          0.030920            0.586465
# 2       C0202             0.781875          0.060995            0.455738
# 3       C0202             1.734875          0.101657            0.303070
# 4       A0201             1.012500          0.158010            0.345066
# 5       A0201             1.093750          0.015113            0.206176
# 6       C0202             2.398000          0.003090            0.158057
# 7       C0202             2.511750          0.026198            0.159450
# 8       A0301             0.970625          0.003090            0.143999
# 9       C0202             2.594750          0.013744            0.146487
#
#    presentation_percentile
# 0                 0.351359
# 1                 0.642908
# 2                 0.920299
# 3                 1.356196
# 4                 1.214701
# 5                 1.801603
# 6                 2.154946
# 7                 2.137962
# 8                 2.292011
# 9                 2.261060

# %%
from mhcflurry import Class1AffinityPredictor

# %%
predictor = Class1AffinityPredictor.load()

# %%
predictor.predict_to_dataframe(allele="HLA-A0201", peptides=["SIINFEKL", "SIINFEQL"])
# Out:
# /usr/local/lib/python3.8/dist-packages/keras/engine/training_v1.py:2357: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
#     peptide     allele    prediction  prediction_low  prediction_high  \
# 0  SIINFEKL  HLA-A0201  11927.159038     6901.077478     18127.364540
# 1  SIINFEQL  HLA-A0201  12070.886650     7362.360508     18465.972483
#
#    prediction_percentile
# 0               6.296000
# 1               6.354125
